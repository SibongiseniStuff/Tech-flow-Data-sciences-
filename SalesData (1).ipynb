# %% [markdown]
# #S.Langa 22522719<br>
# </br> #S.SHELEMBE 22506130<br>
# </br> #SI NUTLI 22404967<br>
#  </br> # NM Nzama 22510310

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales=pd.read_csv('Sales Data.csv')

# %%
sales.head(10)
# Out:
#   Order ID  Year  Month  Date  Province     Salesperson    Product  \
# 0    zl101  2019      1    16  Shanghai         De Tang  Product 1
# 1    zl102  2019      1    16  Shenzhen         De Tang  Product 2
# 2    zl103  2019      1    16  Shenzhen         Bang Li  Product 3
# 3    zl104  2019      1    16  Shanghai         De Tang  Product 1
# 4    zl105  2019      1    16  Shenzhen  Xiangfang Ding  Product 2
# 5    zl106  2019      1    16  Shandong         Bang Li  Product 4
# 6    zl107  2019      1    16  Shenzhen      Dezhu Zhao  Product 3
# 7    zl108  2019      1    16  Shenzhen  Xiangfang Ding  Product 2
# 8    zl109  2019      1    16   Beijing         De Tang  Product 5
# 9    zl110  2019      1    16  Shandong   Zonghong Wang  Product 1
#
#    Sales Volume  Average Transaction Price  Total Sales  Profit Amount  \
# 0           587                         22      12914.0         4062.0
# 1            30                         31        930.0          570.0
# ...

# %%
print(dir(sales))
# Out:
# ['Date', 'Month', 'Product', 'Province', 'Salesperson', 'T', 'Year', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Order ID                   1501 non-null   object
#  1   Year                       1501 non-null   int64
#  2   Month                      1501 non-null   int64
#  3   Date                       1501 non-null   int64
#  4   Province                   1501 non-null   object
#  5   Salesperson                1501 non-null   object
#  6   Product                    1501 non-null   object
#  7   Sales Volume               1501 non-null   int64
#  8   Average Transaction Price  1501 non-null   int64
#  9   Total Sales                1501 non-null   float64
#  10  Profit Amount              1501 non-null   float64
#  11  Unnamed: 11                0 non-null      float64
#  12  Unnamed: 12                0 non-null      float64
# ...

# %%
odata.dropna(inplace=True)

# %%
'The total number of rows after removing all rows:{}'.format(sales.shape[0])
# Out:
# 'The total number of rows after removing all rows:1501'

# %%
sales.dropna(axis=1,how='all')
# Out:
#      Order ID  Year  Month  Date   Province     Salesperson    Product  \
# 0       zl101  2019      1    16   Shanghai         De Tang  Product 1
# 1       zl102  2019      1    16   Shenzhen         De Tang  Product 2
# 2       zl103  2019      1    16   Shenzhen         Bang Li  Product 3
# 3       zl104  2019      1    16   Shanghai         De Tang  Product 1
# 4       zl105  2019      1    16   Shenzhen  Xiangfang Ding  Product 2
# ...       ...   ...    ...   ...        ...             ...        ...
# 1496   zl1597  2022     12    16   Shenzhen         De Tang  Product 4
# 1497   zl1598  2022     12    16    Beijing         Bang Li  Product 2
# 1498   zl1599  2022     12    16  Guangdong         De Tang  Product 2
# 1499   zl1600  2022     12    16   Shenzhen         Bang Li  Product 4
# 1500   zl1601  2022     12    16   Shandong      Dezhu Zhao  Product 5
#
#       Sales Volume  Average Transaction Price  Total Sales  Profit Amount  \
# ...

# %%
sales.drop_duplicates(['Year','Order ID','Salesperson','Product'],inplace=True)

# %%
sales = sales.drop(columns=['Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Order ID                   1501 non-null   object
#  1   Year                       1501 non-null   int64
#  2   Month                      1501 non-null   int64
#  3   Date                       1501 non-null   int64
#  4   Province                   1501 non-null   object
#  5   Salesperson                1501 non-null   object
#  6   Product                    1501 non-null   object
#  7   Sales Volume               1501 non-null   int64
#  8   Average Transaction Price  1501 non-null   int64
#  9   Total Sales                1501 non-null   float64
#  10  Profit Amount              1501 non-null   float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 129.1+ KB

# %%
odata.shape
# Out:
# (0, 14)

# %%
len(sales)
# Out:
# 1501

# %%
sales.sort_values (by='Sales Volume',ascending=False,inplace=True)

# %%
sales.to_csv("cleaned_sales_data.csv", index=False)

# %%
 sales.head(10)
# Out:
#      Order ID  Year  Month  Date   Province     Salesperson    Product  \
# 268     zl369  2019      9    16  Guangdong   Zonghong Wang  Product 1
# 1054   zl1155  2021     11    16   Shandong         De Tang  Product 3
# 1493   zl1594  2022     12    16    Beijing      Dezhu Zhao  Product 5
# 540     zl641  2020      6    16  Guangdong  Xiangfang Ding  Product 3
# 891     zl992  2021      6    16   Shandong  Xiangfang Ding  Product 3
# 984    zl1085  2021      9    16   Shanghai   Zonghong Wang  Product 4
# 490     zl591  2020      5    16  Guangdong         Bang Li  Product 4
# 937    zl1038  2021      7    16   Shanghai      Dezhu Zhao  Product 2
# 1224   zl1325  2022      5    16   Shenzhen   Zonghong Wang  Product 3
# 1353   zl1454  2022      9    16   Shandong      Dezhu Zhao  Product 5
#
#       Sales Volume  Average Transaction Price  Total Sales  Profit Amount
# 268            780                          8       6240.0         5878.0
# ...
